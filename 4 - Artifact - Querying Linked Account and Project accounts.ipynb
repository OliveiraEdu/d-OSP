# %% [markdown]
# **IMPORTANT**
#
# - For requirements and initial setup go to https://github.com/OliveiraEdu/OpenScience/Readme.md;
# - To execute the notebook run all cells.

# %% [markdown]
# # Querying Linked Account and Project accounts

# %% [markdown]
# ## Activities
#
# 1 - Deploys a smart contract into the Iroha 1 blockchain for details (attributes) setting;
#
# 2 - User and Project id extraction from CSVs;
#
# 3 - Queries Iroha 1 for User and Project accounts and checks the present values;
#
# 4 - Sets details for both User and Project accounts in Iroha 1 providing a logical link between them for later references;
#
# 5 - Queries the User and Project accounts again and checks the proper setting of details.

# %% [markdown]
# 1 -  Contract Deployment

# %%
from Crypto.Hash import keccak
import os
import binascii
from iroha import IrohaCrypto
from iroha import Iroha, IrohaGrpc
from iroha.ed25519 import H
import integration_helpers
from iroha.primitive_pb2 import can_set_my_account_detail
import sys
import csv
import json

if sys.version_info[0] < 3:
    raise Exception("Python 3 or a more recent version is required.")

# Load configuration from config.json file
config_path = "config.json"  # Update this path as needed
with open(config_path, "r") as f:
    config = json.load(f)

IROHA_HOST_ADDR = config["IROHA_HOST_ADDR"]
IROHA_PORT = config["IROHA_PORT"]
ADMIN_ACCOUNT_ID = config["ADMIN_ACCOUNT_ID"]
ADMIN_PRIVATE_KEY = config["ADMIN_PRIVATE_KEY"]

iroha = Iroha(ADMIN_ACCOUNT_ID)
net = IrohaGrpc("{}:{}".format(IROHA_HOST_ADDR, IROHA_PORT))

@integration_helpers.trace
def create_contract():
    bytecode = "..."
    """Bytecode was generated using remix editor  https://remix.ethereum.org/ from file detail.sol. """
    tx = iroha.transaction(
        [iroha.command("CallEngine", caller=ADMIN_ACCOUNT_ID, input=bytecode)]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    net.send_tx(tx)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    for status in net.tx_status_stream(tx):
        print(status)
    return hex_hash


@integration_helpers.trace
def set_account_detail(address, account, variable_1, variable_2):
    params = integration_helpers.get_first_four_bytes_of_keccak(
        b"setAccountDetail(string,string,string)"
    )
    no_of_param = 3
    for x in range(no_of_param):
        params = params + integration_helpers.left_padded_address_of_param(
            x, no_of_param
        )
    params = params + integration_helpers.argument_encoding(
        entity_id
    )  # source user or project account id
    params = params + integration_helpers.argument_encoding(variable_1)  # key
    params = params + integration_helpers.argument_encoding(variable_2)  #  value
    tx = iroha.transaction(
        [
            iroha.command(
                "CallEngine", caller=ADMIN_ACCOUNT_ID, callee=address, input=params
            )
        ]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    response = net.send_tx(tx)
    print(response)
    for status in net.tx_status_stream(tx):
        print(status)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    return hex_hash


@integration_helpers.trace
def get_account_details():
    params = integration_helpers.get_first_four_bytes_of_keccak(b"getAccountDetail()")
    no_of_param = 0
    tx = iroha.transaction(
        [
            iroha.command(
                "CallEngine", caller=ADMIN_ACCOUNT_ID, callee=address, input=params
            )
        ]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    response = net.send_tx(tx)
    for status in net.tx_status_stream(tx):
        print(status)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    return hex_hash


hash = create_contract()
address = integration_helpers.get_engine_receipts_address(hash)
integration_helpers.get_engine_receipts_result(hash)
print("done")
# Out:
# 	Entering "create_contract"
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "create_contract"
# 	Entering "get_engine_receipts_address"
# 	Leaving "get_engine_receipts_address"
# 	Entering "get_engine_receipts_result"
#
# 	Leaving "get_engine_receipts_result"
# done

# %% [markdown]
# 1.3 -  Read User and Project accounts from their respective CSVs, based on the positional index `csv_index`

# %%
# Index for rows in both user account and project account CSVs.
csv_index = 32


# Read user account attributes from a csv
def read_user_accounts_from_csv(file_path):
    user_accounts = []
    with open(file_path, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            user_accounts.append({
                'account_id': row['account_id']
            })
    return user_accounts



# Path to the CSV file
user_accounts_csv_file_path = 'datasets/accounts.csv'

# Read accounts from CSV
user_accounts = read_user_accounts_from_csv(user_accounts_csv_file_path)

# Use the [n] account from the CSV for the example, see csv_index
user_account = user_accounts[csv_index]
print(user_account)
print(user_account['account_id'])
# - 

# Read project account attributes from a csv
def read_project_accounts_from_csv(file_path):
    project_accounts = []
    with open(file_path, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            project_accounts.append({
                'account_id': row['project_id']
            })
    return project_accounts

# Path to the CSV file
project_accounts_csv_file_path = 'datasets/projects.csv'

# Read accounts from CSV
project_accounts = read_project_accounts_from_csv(project_accounts_csv_file_path)

# Use the [n] account from the CSV for the example, see csv_index
project_account = project_accounts[csv_index]
print(project_account)
print(project_account['account_id'])

# -
# Out:
# {'account_id': 'boring_payne@test'}
# boring_payne@test
# {'account_id': '69773@test'}
# 69773@test

# %% [markdown]
# 1.5 - Sets details for both User and Project accounts providing a logical link between them for later references.

# %%
entity_id = user_account['account_id']
print(entity_id)
hash = set_account_detail(address, entity_id, "project", project_account['account_id'])

# print ("-" * 20)

entity_id = project_account['account_id']
print(entity_id)
hash = set_account_detail(address, entity_id, "project_owner", user_account['account_id'])
# Out:
# boring_payne@test
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# 69773@test
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"

# %%
#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=user_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
user_account_data = response.account_detail_response
print(f'User Account id = {user_account}, details = {user_account_data.detail}')
# Out:
# User Account id = {'account_id': 'boring_payne@test'}, details = { "admin@test" : { "project" : "69773@test", "user_account_email" : "boring_payne@email.com", "user_account_full_name" : "Boring Payne", "user_account_institution" : "Universidad Autónoma Metropolitan", "user_account_orcid" : "3026-7817-9920-X", "user_private_key" : "b'd784ba8aabf035e7d22e487c3d044f6bf058684fd26551c3278717bd9da603cf'", "user_public_key" : "9394cbf6a1b5ddd52563f1fe360980bbeb71c0d0c82b7413c042cfceb0990b64" } }

# %%
#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=project_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
data = response.account_detail_response
print(f'Project Account id = {project_account}, details = {data.detail}')
# Out:
# Project Account id = {'account_id': '69773@test'}, details = { "admin@test" : { "file_10_CID" : "QmVTTcqbGvYRn7n7uPYwk4vi8NdbeYvnZkX9MVT3byrAx2", "file_10_metadata_CID" : "QmV3MZaeYmmK4MLwpvHpstEjkg9xpeZpY8CkLS8st5tqeP", "file_11_CID" : "QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj", "file_11_metadata_CID" : "QmR9WrcSnjeUomZ35UvHwB6FxVEPqWtppAFyQCsts7T61p", "file_12_CID" : "QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv", "file_12_metadata_CID" : "QmYMUAWmij5SHTJsFDsbkEK7UwaCnQFVngQ3vRkq3vFEWX", "file_1_CID" : "QmWRMwc5taM4BaapEhLPpmZVPrN7WmxoEyyaQvoSgUqfWW", "file_1_metadata_CID" : "QmdQ3Hjcys7hxshT1BRrTDFAeRgvph1nRPFkssNGZnQt2s", "file_2_CID" : "QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs", "file_2_metadata_CID" : "QmcLm4JMfKCPxk5qkyiKdXJVDQdJj9hojkksDBq2cjuv8v", "file_3_CID" : "QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW", "file_3_metadata_CID" : "QmUT8qy3xuDDmjVTxDzRqCDnY1y5611bPkHwWvAfzSVN2Q", "file_4_CID" : "QmZ9tmsiUTt22eyHqkA84wns29sWwZ94LGHBZzUjbaGwFu", "file_4_metadata_CID" : "QmYrd9pkx2oaR6HbDYv7wsCkhScYGGbqeo2SKYBwmrhR25", "file_5_CID" : "QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C", "file_5_metadata_CID" : "QmYxQWac9isgLDvdqwEyv6gNbv4axNDrHbNmXUNL9qBiBg", "file_6_CID" : "QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4", "file_6_metadata_CID" : "QmRQpftc1qbdqfVRdSdawGxrnY98dir3gh8LZSgF2urAKv", "file_7_CID" : "QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW", "file_7_metadata_CID" : "QmPcAbTaNXdGXSP2dcqM3UgT2T7WnaS1aAJTQk1zPWUrmF", "file_8_CID" : "QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ", "file_8_metadata_CID" : "QmXbfcxjH62nNHHAeYCYGG9EyA9acgoin92yT3bUNrSaSf", "file_9_CID" : "QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q", "file_9_metadata_CID" : "QmTbfW51AwREHauQpaRVLZ4F2NT81m5qe2N3WCrYvYw7AV", "project_metadata_cid" : "QmXhHcFRpeyAsGNquSUpw62arxZpTm72pt9mh7W5HG7bgu", "project_owner" : "boring_payne@test" } }

# %% [markdown]
# 1.7 - Queries the user account, locates the project account and queries the project, gets the metadata and files

# %%
from ipfs_functions import *

# Process the account details response
account_details_dict = json.loads(user_account_data.detail)  # Convert the string to a JSON object
ic(account_details_dict)

# Get the value of the dictionary
user_account_metadata = account_details_dict['admin@test']
ic(user_account_metadata['project'])


for key, value in user_account_metadata.items():
    if 'project' in key:  # Check if this is a file CID
            
        ic(key)
        ic(value)
        #Query - GetAccountDetail
        query = iroha.query('GetAccountDetail',account_id = value)
        # ic(query)
        IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
        response = net.send_query(query)
        # ic(response)
        result = response.account_detail_response
        # ic(result)
        # ic(result.detail)        
        # print(f'Project Account id = {value}, details = {result.detail}')
        # details = {result.detail}
        # ic(details)
        # Process the account details response
        details_dict = json.loads(result.detail)  # Convert the string to a JSON object
        # ic(details_dict)

        # # Get the value of the dictionary (the actual file metadata)
        details_metadata = details_dict['admin@test']
        # ic(details_metadata)
        project_metadata_cid = details_metadata['project_metadata_cid']
        # ic(project_metadata_cid)
        project_metadata_json = download_json_from_ipfs(project_metadata_cid)
        ic(project_metadata_json)
# Out:
# ic| account_details_dict: {'admin@test': {'project': '69773@test',
#                                           'user_account_email': 'boring_payne@email.com',
#                                           'user_account_full_name': 'Boring Payne',
#                                           'user_account_institution': 'Universidad Autónoma Metropolitan',
#                                           'user_account_orcid': '3026-7817-9920-X',
#                                           'user_private_key': "b'd784ba8aabf035e7d22e487c3d044f6bf058684fd26551c3278717bd9da603cf'",
#                                           'user_public_key': '9394cbf6a1b5ddd52563f1fe360980bbeb71c0d0c82b7413c042cfceb0990b64'}}
# ic| user_account_metadata['project']: '69773@test'
# ic| key: 'project'
# ic| value: '69773@test'
# ic| project_metadata_json: {'abstract': 'This study explores the impact of AI in carbon neutrality, '
#                                         'focusing on pollution mitigation.',
#                             'end_date': '2021-10-20',
#                             'funding_agency': 'Bill and Melinda Gates Foundation',
#                             'keywords': ['AI', 'carbon neutrality', 'pollution mitigation'],
#                             'location': 'Amazon Rainforest, Brazil',
#                             'start_date': '2019-08-01',
#                             'title': 'Investigating the Role of AI in carbon neutrality'}

# %% [markdown]
# 1.2 -  Sends every file in the `upload` directory to IPFS, extracts theirs respective metadata with Apache Tika and sends it to IPFS, get the CIDs back and store in Iroha as details of the project account.

# %%
#For file handling

# import os
# import json
from tika import parser
from ipfs_functions import *
import icecream as ic

def parse_documents_in_directory(directory_path):
    
    index = 1

    print(user_account['account_id'])
    
    for filename in os.listdir(directory_path):

        # Block 1
        # Skip hidden files by checking if it starts with a dot
        if not os.path.basename(filename).startswith('.'):
            
            file_path = os.path.join(directory_path, filename)
            print(file_path)
            file_cid = upload_file_to_ipfs(file_path)
               
            variable_1 = f"file_{index}_CID"
            print(variable_1)
            
            variable_2 = file_cid
            print (variable_2)

            hash = set_account_detail(address, user_account, variable_1, variable_2)
            
        # Block 2
        # Check if it's a file and not a directory
        # if not os.path.basename(filename).startswith('.'):
            try:
                parsed_document = parser.from_file(file_path)
           
                
                # Check if parsing was successful
                if 'status' in parsed_document and parsed_document['status'] == 200:
                    metadata = parsed_document.get('metadata', {})
                    # print(metadata)
                    metadata_cid = upload_json_to_ipfs(metadata)
                    
                    variable_3 = f"file_{index}_metadata_CID"
                    print (variable_3)

                    variable_4 = metadata_cid
                    print (variable_4)

                    hash = set_account_detail(address, user_account, variable_3, variable_4)
                    
     
                    
                else:
                    print(f"Parsing failed for '{filename}' with status: {parsed_document.get('status')}")
            
            except Exception as e:
                print(f"An error occurred with file '{filename}': {e}")
            
            print ("-" * 40)
            index += 1

# Example usage
parse_documents_in_directory("upload")
# Out:
# boring_payne@test
# upload/assets.csv
# file_1_CID
# QmWRMwc5taM4BaapEhLPpmZVPrN7WmxoEyyaQvoSgUqfWW
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_1_metadata_CID
# QmSmEJpEfJznHEoa78zbgVz85rxaej6Tv8mYQynrY7ryAK
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf
# file_2_CID
# QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_2_metadata_CID
# QmXnDrgxQc1VHv25uCCmLZS5SeA8NNj65RBeEDbVnW2oqE
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Munafò et al. - 2022 - The reproducibility debate is an opportunity, not .pdf
# file_3_CID
# QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_3_metadata_CID
# QmUT8qy3xuDDmjVTxDzRqCDnY1y5611bPkHwWvAfzSVN2Q
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/assets.json
# file_4_CID
# QmZ9tmsiUTt22eyHqkA84wns29sWwZ94LGHBZzUjbaGwFu
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_4_metadata_CID
# QmR3GKS9vHtm4KqrrAAwjHp1p78v3yAoiFt5SeABtCCUdN
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf
# file_5_CID
# QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_5_metadata_CID
# QmR6puBfy5DQ2BEMgxT7TdDidmgev51MLwMM3Ckx6qrm2m
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf
# file_6_CID
# QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_6_metadata_CID
# QmWKEzLFp9sm9uFPNV6YTSWs7ggHxFYpxzyDquVoEwP5mj
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf
# file_7_CID
# QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_7_metadata_CID
# QmPiZKhXpmKCJ7scjBNGeU2BxuDEac3AaDrNr55PwPuZZV
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/World_Energy_By_Country_And_Region_1965_to_2023.csv
# file_8_CID
# QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_8_metadata_CID
# QmbTDzCwqQZNiz5Q2iWFwoErZFZpVmrbsVkXSdapaNdGSV
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf
# file_9_CID
# QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_9_metadata_CID
# QmWV62aRc4U727fqGzQFF6fDHiJjNXx5WTCj5mY18QawiP
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/Jean-Baptiste_Perronneau_-_Magdaleine_Pinceloup_de_la_Grange,_née_de_Parseval.jpg
# file_10_CID
# QmVTTcqbGvYRn7n7uPYwk4vi8NdbeYvnZkX9MVT3byrAx2
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_10_metadata_CID
# QmVE29saGYyXmWfBQXb8DVW8moRfQXwwZ4dHqVFwbLDHDy
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/bitcoin.pdf
# file_11_CID
# QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_11_metadata_CID
# QmRU9AkPhGSZESPeADSUmfLeGKdw2BVDpB22bEYQpY9nd1
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# upload/hello_world.py
# file_12_CID
# QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# file_12_metadata_CID
# QmYMUAWmij5SHTJsFDsbkEK7UwaCnQFVngQ3vRkq3vFEWX
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------

# %% [markdown]
# Read CIDs from Iroha and download file metadata and files from IPFS to the project home directory

# %%
from ipfs_functions import *
from clean_file_name import *

# Process the account details response
account_details_dict = json.loads(data.detail)  # Convert the string to a JSON object
# ic(account_details_dict)

# Get the value of the dictionary (the actual file metadata)
files_metadata = account_details_dict['admin@test']
ic(files_metadata)

for key, value in files_metadata.items():
    if 'metadata_CID' not in key:  # Check if this is a file CID
        key = '_'.join(key.split('_')[:-1])+"_CID"    
        # ic(key)
        file_CID = value
        # ic(value)
        
    else:
        file_metadata_key = '_'.join(key.split('_')[:-2])  # Extract the actual filename from the key
        ic(file_metadata_key)
        file_metadata_CID = value  # Get the corresponding metadata CID
        ic(file_metadata_CID)
        # print(f"Downloading {file_metadata_CID} metadata...")
        file_metadata_json = download_json_from_ipfs(file_metadata_CID)
        # ic(file_metadata_json)
        if 'resourceName' in file_metadata_json:  # check if key exists in the dictionary
            raw_original_file_name = file_metadata_json['resourceName']
            ic(raw_original_file_name)
            clean_original_file_name = clean_file_name(raw_original_file_name)  # Remove the 'b' prefix and quotes
            ic(clean_original_file_name)

            # Create a home directory for the user with the account ID as the username under /download/
            user_id = project_account['account_id']
            download_directory = os.path.join("download", user_id)
            if not os.path.exists(download_directory):
                os.makedirs(download_directory)  # Create the directory if it doesn't exist

            file_path = os.path.join(download_directory, clean_original_file_name)
            download_file_from_ipfs(file_CID, file_path)
# Out:
# ic| files_metadata: {'file_10_CID': 'QmVTTcqbGvYRn7n7uPYwk4vi8NdbeYvnZkX9MVT3byrAx2',
#                      'file_10_metadata_CID': 'QmV3MZaeYmmK4MLwpvHpstEjkg9xpeZpY8CkLS8st5tqeP',
#                      'file_11_CID': 'QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj',
#                      'file_11_metadata_CID': 'QmR9WrcSnjeUomZ35UvHwB6FxVEPqWtppAFyQCsts7T61p',
#                      'file_12_CID': 'QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv',
#                      'file_12_metadata_CID': 'QmYMUAWmij5SHTJsFDsbkEK7UwaCnQFVngQ3vRkq3vFEWX',
#                      'file_1_CID': 'QmWRMwc5taM4BaapEhLPpmZVPrN7WmxoEyyaQvoSgUqfWW',
#                      'file_1_metadata_CID': 'QmdQ3Hjcys7hxshT1BRrTDFAeRgvph1nRPFkssNGZnQt2s',
#                      'file_2_CID': 'QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs',
#                      'file_2_metadata_CID': 'QmcLm4JMfKCPxk5qkyiKdXJVDQdJj9hojkksDBq2cjuv8v',
#                      'file_3_CID': 'QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW',
#                      'file_3_metadata_CID': 'QmUT8qy3xuDDmjVTxDzRqCDnY1y5611bPkHwWvAfzSVN2Q',
#                      'file_4_CID': 'QmZ9tmsiUTt22eyHqkA84wns29sWwZ94LGHBZzUjbaGwFu',
#                      'file_4_metadata_CID': 'QmYrd9pkx2oaR6HbDYv7wsCkhScYGGbqeo2SKYBwmrhR25',
#                      'file_5_CID': 'QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C',
#                      'file_5_metadata_CID': 'QmYxQWac9isgLDvdqwEyv6gNbv4axNDrHbNmXUNL9qBiBg',
#                      'file_6_CID': 'QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4',
#                      'file_6_metadata_CID': 'QmRQpftc1qbdqfVRdSdawGxrnY98dir3gh8LZSgF2urAKv',
#                      'file_7_CID': 'QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW',
#                      'file_7_metadata_CID': 'QmPcAbTaNXdGXSP2dcqM3UgT2T7WnaS1aAJTQk1zPWUrmF',
#                      'file_8_CID': 'QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ',
#                      'file_8_metadata_CID': 'QmXbfcxjH62nNHHAeYCYGG9EyA9acgoin92yT3bUNrSaSf',
#                      'file_9_CID': 'QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q',
#                      'file_9_metadata_CID': 'QmTbfW51AwREHauQpaRVLZ4F2NT81m5qe2N3WCrYvYw7AV',
#                      'project_metadata_cid': 'QmXhHcFRpeyAsGNquSUpw62arxZpTm72pt9mh7W5HG7bgu',
#                      'project_owner': 'boring_payne@test'}
# ic| file_metadata_key: 'file_10'
# ic| file_metadata_CID: 'QmV3MZaeYmmK4MLwpvHpstEjkg9xpeZpY8CkLS8st5tqeP'
# ic| raw_original_file_name: "b'Jean-Baptiste_Perronneau_-_Magdaleine_Pinceloup_de_la_Grange,_n\\xc3\\xa9e_de_Parseval.jpg'"
# ic| clean_original_file_name: 'Jean-Baptiste_Perronneau_-_Magdaleine_Pinceloup_de_la_Grange,_née_de_Parseval.jpg'
# ic| file_metadata_key: 'file_11'
# ic| file_metadata_CID: 'QmR9WrcSnjeUomZ35UvHwB6FxVEPqWtppAFyQCsts7T61p'
# ic| raw_original_file_name: "b'bitcoin.pdf'"
# ic| clean_original_file_name: 'bitcoin.pdf'
# ic| file_metadata_key: 'file_12'
# ic| file_metadata_CID: 'QmYMUAWmij5SHTJsFDsbkEK7UwaCnQFVngQ3vRkq3vFEWX'
# ic| raw_original_file_name: "b'hello_world.py'"
# ic| clean_original_file_name: 'hello_world.py'
# ic| file_metadata_key: 'file_1'
# ic| file_metadata_CID: 'QmdQ3Hjcys7hxshT1BRrTDFAeRgvph1nRPFkssNGZnQt2s'
# ic| raw_original_file_name: "b'assets.csv'"
# ic| clean_original_file_name: 'assets.csv'
# ic| file_metadata_key: 'file_2'
# ic| file_metadata_CID: 'QmcLm4JMfKCPxk5qkyiKdXJVDQdJj9hojkksDBq2cjuv8v'
# ic| raw_original_file_name: "b'Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf'"
# ic| clean_original_file_name: 'Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf'
# ic| file_metadata_key: 'file_3'
# ic| file_metadata_CID: 'QmUT8qy3xuDDmjVTxDzRqCDnY1y5611bPkHwWvAfzSVN2Q'
# ic| raw_original_file_name: ("b'Munaf\\xc3\\xb2 et al. - 2022 - The reproducibility debate is an "
#                              "opportunity, not .pdf'")
# ic| clean_original_file_name: 'Munafò et al. - 2022 - The reproducibility debate is an opportunity, not .pdf'
# ic| file_metadata_key: 'file_4'
# ic| file_metadata_CID: 'QmYrd9pkx2oaR6HbDYv7wsCkhScYGGbqeo2SKYBwmrhR25'
# ic| raw_original_file_name: "b'assets.json'"
# ic| clean_original_file_name: 'assets.json'
# ic| file_metadata_key: 'file_5'
# ic| file_metadata_CID: 'QmYxQWac9isgLDvdqwEyv6gNbv4axNDrHbNmXUNL9qBiBg'
# ic| raw_original_file_name: "b'Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf'"
# ic| clean_original_file_name: 'Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf'
# ic| file_metadata_key: 'file_6'
# ic| file_metadata_CID: 'QmRQpftc1qbdqfVRdSdawGxrnY98dir3gh8LZSgF2urAKv'
# ic| raw_original_file_name: "b'Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf'"
# ic| clean_original_file_name: 'Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf'
# ic| file_metadata_key: 'file_7'
# ic| file_metadata_CID: 'QmPcAbTaNXdGXSP2dcqM3UgT2T7WnaS1aAJTQk1zPWUrmF'
# ic| raw_original_file_name: "b'COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf'"
# ic| clean_original_file_name: 'COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf'
# ic| file_metadata_key: 'file_8'
# ic| file_metadata_CID: 'QmXbfcxjH62nNHHAeYCYGG9EyA9acgoin92yT3bUNrSaSf'
# ic| raw_original_file_name: "b'World_Energy_By_Country_And_Region_1965_to_2023.csv'"
# ic| clean_original_file_name: 'World_Energy_By_Country_And_Region_1965_to_2023.csv'
# ic| file_metadata_key: 'file_9'
# ic| file_metadata_CID: 'QmTbfW51AwREHauQpaRVLZ4F2NT81m5qe2N3WCrYvYw7AV'
# ic| raw_original_file_name: "b'Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf'"
# ic| clean_original_file_name: 'Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf'
