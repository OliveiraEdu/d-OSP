# %% [markdown]
# # 2 - Artifact - User Account Detail Batch Setting

# %% [markdown]
# 2. 1 - Overview
#
# This notebook deploys a contract for account detail setting and than read key/values pairs for each account at `datatase/accounts.csv` and set account details in batch.

# %%
from Crypto.Hash import keccak
import os
import binascii
from iroha import IrohaCrypto
from iroha import Iroha, IrohaGrpc
from iroha.ed25519 import H
import integration_helpers
from iroha.primitive_pb2 import can_set_my_account_detail
import sys
import csv
import json



if sys.version_info[0] < 3:
    raise Exception("Python 3 or a more recent version is required.")

# Load configuration from config.json file
config_path = "config.json"  # Update this path as needed
with open(config_path, "r") as f:
    config = json.load(f)

IROHA_HOST_ADDR = config["IROHA_HOST_ADDR"]
IROHA_PORT = config["IROHA_PORT"]
ADMIN_ACCOUNT_ID = config["ADMIN_ACCOUNT_ID"]
ADMIN_PRIVATE_KEY = config["ADMIN_PRIVATE_KEY"]

iroha = Iroha(ADMIN_ACCOUNT_ID)
net = IrohaGrpc("{}:{}".format(IROHA_HOST_ADDR, IROHA_PORT))

@integration_helpers.trace
def create_contract():
    bytecode = "..."
    """Bytecode was generated using remix editor  https://remix.ethereum.org/ from file detail.sol. """
    tx = iroha.transaction(
        [iroha.command("CallEngine", caller=ADMIN_ACCOUNT_ID, input=bytecode)]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    net.send_tx(tx)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    for status in net.tx_status_stream(tx):
        print(status)
    return hex_hash

@integration_helpers.trace
def set_account_detail(address, account, key, value):
    params = integration_helpers.get_first_four_bytes_of_keccak(
        b"setAccountDetail(string,string,string)"
    )
    no_of_param = 3
    for x in range(no_of_param):
        params = params + integration_helpers.left_padded_address_of_param(
            x, no_of_param
        )
    params = params + integration_helpers.argument_encoding(account)  # source account id
    params = params + integration_helpers.argument_encoding(key)  # key
    params = params + integration_helpers.argument_encoding(value)  #  value
    tx = iroha.transaction(
        [
            iroha.command(
                "CallEngine", caller=ADMIN_ACCOUNT_ID, callee=address, input=params
            )
        ]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    response = net.send_tx(tx)
    print(response)
    for status in net.tx_status_stream(tx):
        print(status)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    return hex_hash





# - Deploys the contract
hash = create_contract()
address = integration_helpers.get_engine_receipts_address(hash)
integration_helpers.get_engine_receipts_result(hash)

# - Reads the accounts dataset and set account_id and additional key/value pairs
with open('datasets/accounts.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        account_id = row['account_id']
        for key, value in row.items():
            if key != 'account_id':
                print(f"{account_id}")
                print(f"{key}: {value}")
                hash = set_account_detail(address, account_id, key, value)
# Out:
# 	Entering "create_contract"
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "create_contract"
# 	Entering "get_engine_receipts_address"
# 	Leaving "get_engine_receipts_address"
# 	Entering "get_engine_receipts_result"
#
# 	Leaving "get_engine_receipts_result"
# agitated_bartik@test
# user_account_full_name: Agitated Bartik
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_email: agitated_bartik@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_institution: Pak-AIMS (American Institute of Management Sciences)
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_orcid: 6761-5714-3845-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_private_key: b'c7e6254dec78949adb31c86d3fdbc9415621af9f292081d3a455b1ffa756c430'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_public_key: 8520e544b0afb0708e5b2a591f5ea01a5bf6c5720bcea6a4c1c7f0f138a4f164
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_account_full_name: Xenodochial Pare
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_account_email: xenodochial_pare@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_account_institution: Anambra State University of Science and Technology
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_account_orcid: 1258-2042-9603-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_private_key: b'cdbc2f82e25d1c8ab98301952bfa5cfcf666715de0f14bd07e5856e3fde9d10a'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# xenodochial_pare@test
# user_public_key: a493bc707659b07ef36d06ea2ce625b1e9027674ef87f020dda6c804d97f7d7f
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_account_full_name: Silly Lederberg
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_account_email: silly_lederberg@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_account_institution: Instituto Politécnico de Castelo Branco
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_account_orcid: 1320-0340-5590-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_private_key: b'8b506493c65427cbdd7cce02d41ffada0079b57372f191b1f5a179dd613ac5cf'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# silly_lederberg@test
# user_public_key: dca5fef0934da6757dc3c438d2ce1e7eef7f789e69f05cfa46b7b0b8d27713f1
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_account_full_name: Elegant Cabrera
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_account_email: elegant_cabrera@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_account_institution: Franklin College Switzerland
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_account_orcid: 3144-6809-9103-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_private_key: b'4105b2d773a48e7e00ca10d87ed92519aafb0baf16fbbe96bc200926b54f409e'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_cabrera@test
# user_public_key: 611154c9847a3f4181fe7d9d84f7482752fc2aa7f9534267ac26cad5da11c34a
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_account_full_name: Jolly Murdock
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_account_email: jolly_murdock@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_account_institution: Universidad Autónoma de Tamaulipas
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_account_orcid: 1054-0504-8127-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_private_key: b'39ca4fe5723186e14efe1698df1984e2cf8e9c5583fe2038d978c7b79cc079a1'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# jolly_murdock@test
# user_public_key: 4775ceb8e41e4ef8e950cf7fef5237c9e8124aeff3c020a6a6b831481417a008
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_account_full_name: Nervous Hamilton
# 	Entering "set_account_detail"
# None
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_account_email: nervous_hamilton@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_account_institution: New England School of Communications
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_account_orcid: 9942-4174-3274-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_private_key: b'5d5fcd80a8b3977d1cb02433b874cb609648066c965d5bbfe2dd3b4136bb5e8b'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# nervous_hamilton@test
# user_public_key: fc2ca7b40caa99805ba78a143a37caf912ed4b8cb633ff82fd698ea866c95e67
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_account_full_name: Lucid Morse
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_account_email: lucid_morse@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_account_institution: University of Reading
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_account_orcid: 7676-1729-1844-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_private_key: b'3b5ac67ec745fbd3d26bca1843ee7a42104c03f041c3be5cefd2e03cc0258df2'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# lucid_morse@test
# user_public_key: a8391a29c26146dc51b8046bc81f3e5cd3361109fd4bc2abbf9090436ed45090
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_account_full_name: Competent Morse
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_account_email: competent_morse@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_account_institution: Universidad de Monterrey
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_account_orcid: 0573-7863-2199-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_private_key: b'111ea79bc2ab58a393a873db83a9da2992796c1bc1197f2b8b1f310370f510d5'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# competent_morse@test
# user_public_key: f18429446420d9474fff62588760ed1dec67d091ed3a7e7300259810f3aab12a
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_account_full_name: Keen Goldstine
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_account_email: keen_goldstine@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_account_institution: Institut Supérieur d'Agriculture Lille
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_account_orcid: 7730-6274-9709-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_private_key: b'012d5a72ddcadeddeeef0f52e5ea9606e5f082acbf0b4a04b77a2ee78fe5a7ac'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# keen_goldstine@test
# user_public_key: 847ad7908d90b83588cf6478433c5a2c099560cd27bc087bb432696b37298993
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_account_full_name: Gifted Grothendieck
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_account_email: gifted_grothendieck@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_account_institution: Illinois Institute of Technology
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_account_orcid: 8082-9773-0955-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_private_key: b'338c87e0c474b332dc210299f013f8db9390ed07a648921ef7f1211280e5fa50'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# gifted_grothendieck@test
# user_public_key: 0d7a52b567b57e1755f3a928cc2dceeffe90b54a29e73b796f331073208e60c8
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_account_full_name: Vigorous Khayyam
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_account_email: vigorous_khayyam@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_account_institution: Daniel Webster College
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_account_orcid: 5575-3697-5104-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_private_key: b'abee112bad494be2fca048fd429d98a6daf0ad90880871eaacf9e9f13956abf1'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# vigorous_khayyam@test
# user_public_key: d5c256be4494697650c3807e85de3805a056f7b5f8cb8d53d46349d3734b48cd
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_account_full_name: Boring Payne
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_account_email: boring_payne@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_account_institution: Universidad Autónoma Metropolitana
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_account_orcid: 3026-7817-9920-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_private_key: b'd784ba8aabf035e7d22e487c3d044f6bf058684fd26551c3278717bd9da603cf'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_payne@test
# user_public_key: 9394cbf6a1b5ddd52563f1fe360980bbeb71c0d0c82b7413c042cfceb0990b64
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_account_full_name: Intelligent Blackwell
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_account_email: intelligent_blackwell@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_account_institution: Lander University
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_account_orcid: 5964-7691-9294-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_private_key: b'49f6afce0397449b099bcfd20d975f0dee503f2152ab9fd10803de43e839cec6'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# intelligent_blackwell@test
# user_public_key: 0d548d58b555bf536532b7ac69e0af6166973b2f8d52026d07adc451939d385b
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_account_full_name: Clever Pike
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_account_email: clever_pike@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_account_institution: Oklahoma State University
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_account_orcid: 9433-9845-8963-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_private_key: b'3f75fa00ed6509f7316e3cd28accef2745d867c12788dfcce314b6f1d410e45a'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# clever_pike@test
# user_public_key: 6799e6804bec84ed51e28c19db1d3ce47de36b6c970c34f98fd8235650240974
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_account_full_name: Sharp Ptolemy
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_account_email: sharp_ptolemy@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_account_institution: University of Montana Western
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_account_orcid: 3513-4109-9825-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_private_key: b'e829e39863b2002e49402b16209349bb13d9906f23ca4b1d641a9b0b7e70f7ca'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# sharp_ptolemy@test
# user_public_key: 402ae7f14346dd0c9a15da1bc43d90a471fb5b4a99cc7e3d6f7492b9dfb767e1
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_account_full_name: Recursing Panini
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_account_email: recursing_panini@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_account_institution: Science University of Tokyo in Yamaguchi
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_account_orcid: 2160-8983-6717-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_private_key: b'da8b8d577d6833193641bb523e234688803a53a2f0b3fbb423241bdb8a8548d2'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# recursing_panini@test
# user_public_key: 4fb5a5460c5fbb750bcc857f30a0b881670c63288f1beb00a6f510fdf8c4c2e6
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_account_full_name: Elegant Pike
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_account_email: elegant_pike@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_account_institution: Al-Wataniya Private University
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_account_orcid: 8074-5283-8494-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_private_key: b'98717e7ca5bd868a61da1c1245b1089e7bd526b77741de059c9873de30ba2a70'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# elegant_pike@test
# user_public_key: f6dbe04be1d1b54aa74a9769c3ae8996208c97ca9d80b60f22b24b3a34b3903f
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_account_full_name: Priceless Babbage
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_account_email: priceless_babbage@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_account_institution: Erasmushogeschool Brussel
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_account_orcid: 6851-5211-1192-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_private_key: b'698935ed140ae58e786644a3179a379257f358b222a5e91221c66e34d13f1fd9'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# priceless_babbage@test
# user_public_key: ec7c75255f24edf08995b292225c974ae74e15d259cdb768cb4d234e19b8f89c
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_account_full_name: Compassionate Poitras
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_account_email: compassionate_poitras@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_account_institution: Rutgers, The State University of New Jersey - Newark
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_account_orcid: 5649-8586-3043-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_private_key: b'a2effdb87b15ffe8bbe7521e0de4c5c9f1f982d89aa7a39c0d9bcee466c1ce74'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# compassionate_poitras@test
# user_public_key: 05f524ab8fd7c837040ab1eee9c6f8a4af1e45cb45b8af2c8d3ea74cf1bb1f13
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_account_full_name: Boring Lewin
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_account_email: boring_lewin@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_account_institution: Ludwik Solski State Academy of Theatre in Cracow
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_account_orcid: 9248-8558-3658-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_private_key: b'49fa3696a5aa511d2594a8d9ebf04d0a286d2bb614688abf89ec16f5d4bccc4c'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# boring_lewin@test
# user_public_key: 2dfe88b2968625ffc7271dcec132b8285d2795fca3cff70010d7e7945e7c5acf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_account_full_name: Condescending Pasteur
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_account_email: condescending_pasteur@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_account_institution: Universidad Nacional de Mar del Plata
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_account_orcid: 8252-3251-7000-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_private_key: b'4aaff688bd2f36806023ef20cfa22c749450cb81f1e1f0a3aa407bcf05e8019a'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# condescending_pasteur@test
# user_public_key: dcc7092e9120e5a12187ee8967d680cbd2c944fb4844e083ed0bb988d352f14a
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_full_name: Agitated Bartik
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_email: agitated_bartik@email.com
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_institution: Pak-AIMS (American Institute of Management Sciences)
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_account_orcid: 6761-5714-3845-X
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_private_key: b'c7e6254dec78949adb31c86d3fdbc9415621af9f292081d3a455b1ffa756c430'
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# user_public_key: 8520e544b0afb0708e5b2a591f5ea01a5bf6c5720bcea6a4c1c7f0f138a4f164
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# agitated_bartik@test
# None: ['done']
# 	Entering "set_account_detail"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 91
#      89 print(f"{account_id}")
#      90 print(f"{key}: {value}")
# ---> 91 hash = set_account_detail(address, account_id, key, value)
#
# File ~/OpenScience/integration_helpers.py:32, in trace.<locals>.tracer(*args, **kwargs)
#      30 name = func.__name__
#      31 print('\tEntering "{}"'.format(name))
# ---> 32 result = func(*args, **kwargs)
#      33 print('\tLeaving "{}"'.format(name))
#      34 return result
#
# Cell In[11], line 56, in set_account_detail(address, account, key, value)
#      52     params = params + integration_helpers.left_padded_address_of_param(
#      53         x, no_of_param
#      54     )
#      55 params = params + integration_helpers.argument_encoding(account)  # source account id
# ---> 56 params = params + integration_helpers.argument_encoding(key)  # key
#      57 params = params + integration_helpers.argument_encoding(value)  #  value
#      58 tx = iroha.transaction(
#      59     [
#      60         iroha.command(
#    (...)
#      63     ]
#      64 )
#
# File ~/OpenScience/integration_helpers.py:56, in argument_encoding(arg)
#      54 def argument_encoding(arg):
#      55     """Encodes the argument according to Contract ABI specifications."""
# ---> 56     encoded_argument = str(hex(len(arg)))[2:].zfill(64)
#      57     encoded_argument = (
#      58         encoded_argument + arg.encode("utf8").hex().ljust(64, "0").upper()
#      59     )
#      60     return encoded_argument
#
# TypeError: object of type 'NoneType' has no len()
