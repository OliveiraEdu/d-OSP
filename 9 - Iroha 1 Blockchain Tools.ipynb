# %% [markdown]
# # Notebook 9 - Iroha 1 Blockchain Tools
#
# [From Python Iroha Examples](https://github.com/hyperledger-iroha/iroha-python/tree/1.1.3/examples)

# %% [markdown]
# ## Get Blocks
#
# [Infinite Block Stream](examples/infinite-blocks-stream.py)
#
# Interrupt execution to stop streaming.

# %%
from integration_helpers import get_blocks
# from iroha_helper import *

# %%
get_blocks()
# Out:
# 2025-02-08 22:15:18.323 | DEBUG    | integration_helpers:tracer:35 - 	Entering "get_blocks"
# 2025-02-08 22:15:28.231 | INFO     | integration_helpers:get_blocks:156 - The next block arrived: block_response {
#   block {
#     block_v1 {
#       payload {
#         transactions {
#           payload {
#             reduced_payload {
#               commands {
#                 call_engine {
#                   caller: "admin@test"
#                   callee: "93F622673AA712B7298FDD2212E3228D8D9DD8BF"
#                   input: "..."
#                 }
#               }
#               creator_account_id: "admin@test"
#               created_time: 1739052925202
#               quorum: 1
#             }
#           }
#           signatures {
#             public_key: "313a07e6384776ed95447710d15e59148473ccfc052a681317a72a69f2a49910"
# ...
