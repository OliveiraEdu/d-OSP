# %% [markdown]
# **IMPORTANT**
#
# - For requirements and initial setup go to https://github.com/OliveiraEdu/OpenScience/Readme.md;
# - To execute the notebook run all cells.

# %% [markdown]
#  # Cross Linking Account and Project accounts, IPFS Search Engine implementation.

# %% [markdown]
# # Part - 1 Cross Linking Account and Project accounts

# %% [markdown]
# ## Activities
#
# 1 - Deploys a smart contract into the Iroha 1 blockchain for details (attributes) setting;
#
# 2 - User and Project id extraction from CSVs;
#
# 3 - Queries Iroha 1 for User and Project accounts and checks the present values;
#
# 4 - Sets details for both User and Project accounts in Iroha 1 providing a logical link between them for later references;
#
# 5 - Queries the User and Project accounts again and checks the proper setting of details.

# %% [markdown]
# ## Sequence Diagram

# %% [markdown]
# ```mermaid
#
# %%{
#   init: {
#     'theme': 'base',
#     'themeVariables': {
#       'primaryColor': '#ffffff',
#       'primaryTextColor': '#000000',
#       'primaryBorderColor': '#000000',
#       'lineColor': '#000000',
#       'secondaryColor': '#f4f4f4',
#       'secondaryTextColor': '#000000',
#       'tertiaryColor': '#d3d3d3',
#       'tertiaryTextColor': '#000000',
#       'background': '#ffffff',
#       'actorBkg': '#B4B4B4',
#       'actorTextColor': '#000000',
#       'actorBorder': '#000000',
#       'actorLineColor': '#000000',
#       'signalColor': '#000000',
#       'signalTextColor': '#000000',
#       'activationBorderColor': '#000000',
#       'activationBkgColor': '#d3d3d3',
#       'sequenceNumberColor': '#000000',
#       'noteBkgColor': '#F0F0F0',
#       'noteTextColor': '#000000',
#       'noteBorderColor': '#000000'
#     }
#   }
# }%%
#
# sequenceDiagram
#     participant Platform as "Platform"
#     participant Blockchain as "Iroha 1 Blockchain"
#
#     Note over Platform, Blockchain: Deploy smart contract for details setting
#     Platform->>Blockchain: Deploy Smart Contract
#     Blockchain->>Platform: Smart Contract Deployed Successfully
#
#     Note over Platform, Blockchain: Extract user and project IDs from CSVs
#     Platform->>self: User ID Extraction
#     Platform->>self: Project ID Extraction
#
#     Note over Platform, Blockchain: Queries the blockchain for User and Project accounts details
#     Platform->>Blockchain: Get User Account Details
#     Blockchain->>Platform: Query Response
#     Platform->>Blockchain: Get Project Account Details
#     Blockchain->>Platform: Query Response
#
#     Note over Platform, Blockchain: Set details for User and Project accounts
#     Platform->>Blockchain: Set User Details in Blockchain
#     Blockchain->>Platform: User Details Set Successfully
#     Platform->>Blockchain: Set Project Details in Blockchain
#     Blockchain->>Platform: Project Details Set Successfully
#
#     Note over Platform, Blockchain: Queries the blockchain to confirm proper setting of details
#     Platform->>Blockchain: Get User Account Details
#     Blockchain->>Platform: Query Response
#     Platform->>Blockchain: Get Project Account Details
#     Blockchain->>Platform: Query Response
#
# ```

# %% [markdown]
# 1 - Deploys a smart contract into the Iroha 1 blockchain for details (attributes) setting;

# %%
from Crypto.Hash import keccak
import os
import binascii
from iroha import IrohaCrypto
from iroha import Iroha, IrohaGrpc
from iroha.ed25519 import H
import integration_helpers
from iroha.primitive_pb2 import can_set_my_account_detail
import sys
import csv
import json

if sys.version_info[0] < 3:
    raise Exception("Python 3 or a more recent version is required.")

# Load configuration from config.json file
config_path = "config.json"  # Update this path as needed
with open(config_path, "r") as f:
    config = json.load(f)

IROHA_HOST_ADDR = config["IROHA_HOST_ADDR"]
IROHA_PORT = config["IROHA_PORT"]
ADMIN_ACCOUNT_ID = config["ADMIN_ACCOUNT_ID"]
ADMIN_PRIVATE_KEY = config["ADMIN_PRIVATE_KEY"]

iroha = Iroha(ADMIN_ACCOUNT_ID)
net = IrohaGrpc("{}:{}".format(IROHA_HOST_ADDR, IROHA_PORT))


@integration_helpers.trace
def create_contract():
    bytecode = "..."
    """Bytecode was generated using remix editor  https://remix.ethereum.org/ from file detail.sol. """
    tx = iroha.transaction(
        [iroha.command("CallEngine", caller=ADMIN_ACCOUNT_ID, input=bytecode)]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    net.send_tx(tx)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    for status in net.tx_status_stream(tx):
        print(status)
    return hex_hash

hash = create_contract()
integration_helpers.get_engine_receipts_result(hash)
print("done")
# Out:
# 	Entering "create_contract"
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "create_contract"
# 	Entering "get_engine_receipts_result"
#
# 	Leaving "get_engine_receipts_result"
# done

# %% [markdown]
# 2 - Data extraction from CSVs.
#
# Extracts account ids from `datasets/accounts.csv` and `datasets/projects.csv`.
#
# Must update `csv_index` with a line number related to an existing row in `datasets/accounts.csv` and `datasets/projects.csv`

# %%
# Index for rows in both user account and project account CSVs.
csv_index = 2

# %%
@integration_helpers.trace
def set_account_detail(address, account, variable_1, variable_2):
    params = integration_helpers.get_first_four_bytes_of_keccak(
        b"setAccountDetail(string,string,string)"
    )
    no_of_param = 3
    for x in range(no_of_param):
        params = params + integration_helpers.left_padded_address_of_param(
            x, no_of_param
        )
    params = params + integration_helpers.argument_encoding(
        entity_id
    )  # source user or project account id
    params = params + integration_helpers.argument_encoding(variable_1)  # key
    params = params + integration_helpers.argument_encoding(variable_2)  #  value
    tx = iroha.transaction(
        [
            iroha.command(
                "CallEngine", caller=ADMIN_ACCOUNT_ID, callee=address, input=params
            )
        ]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    response = net.send_tx(tx)
    print(response)
    for status in net.tx_status_stream(tx):
        print(status)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    return hex_hash


@integration_helpers.trace
def get_account_details():
    params = integration_helpers.get_first_four_bytes_of_keccak(b"getAccountDetail()")
    no_of_param = 0
    tx = iroha.transaction(
        [
            iroha.command(
                "CallEngine", caller=ADMIN_ACCOUNT_ID, callee=address, input=params
            )
        ]
    )
    IrohaCrypto.sign_transaction(tx, ADMIN_PRIVATE_KEY)
    response = net.send_tx(tx)
    for status in net.tx_status_stream(tx):
        print(status)
    hex_hash = binascii.hexlify(IrohaCrypto.hash(tx))
    return hex_hash


address = integration_helpers.get_engine_receipts_address(hash)

print(csv_index)

# Reads user account attributes from a datasets/accounts.csv
def read_user_accounts_from_csv(file_path):
    user_accounts = []
    with open(file_path, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            user_accounts.append({
                'account_id': row['account_id']
            })
    return user_accounts


# Path to the CSV file
user_accounts_csv_file_path = 'datasets/accounts.csv'

# Read accounts from CSV
user_accounts = read_user_accounts_from_csv(user_accounts_csv_file_path)
print (user_accounts)

# Use the [n] row from the CSV for the example
user_account = user_accounts[csv_index]
print(csv_index)
print(user_account)
print(user_account['account_id'])

 

# Reads project account attributes from csv datasets/projects.csv
def read_project_accounts_from_csv(file_path):
    project_accounts = []
    with open(file_path, mode='r') as file:
        csv_reader = csv.DictReader(file)
        for row in csv_reader:
            project_accounts.append({
                'account_id': row['project_id']
            })
    return project_accounts

# Path to the CSV file
project_accounts_csv_file_path = 'datasets/projects.csv'

# Read accounts from CSV
project_accounts = read_project_accounts_from_csv(project_accounts_csv_file_path)

# Use the [n] row from the CSV for the example
project_account = project_accounts[csv_index]
print(project_account)
print(project_account['account_id'])
# Out:
# 	Entering "get_engine_receipts_address"
# 	Leaving "get_engine_receipts_address"
# 2
# [{'account_id': 'pedantic_payne@test'}, {'account_id': 'nifty_murdock@test'}, {'account_id': 'compassionate_nash@test'}]
# 2
# {'account_id': 'compassionate_nash@test'}
# compassionate_nash@test
# {'account_id': '82137@test'}
# 82137@test

# %% [markdown]
# 3 - Queries Iroha 1 for User and Project accounts and checks the present values

# %%
#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=user_account['account_id'])
print(query)
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
print(response)
data = response.account_detail_response
print(f'User Account id = {user_account}, details = {data.detail}')

print ("-" * 20)

#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=project_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
print(response)
data = response.account_detail_response
print(f'Project Account id = {project_account}, details = {data.detail}')
# Out:
# payload {
#   meta {
#     created_time: 1728860669211
#     creator_account_id: "admin@test"
#     query_counter: 1
#   }
#   get_account_detail {
#     account_id: "compassionate_nash@test"
#   }
# }
#
# account_detail_response {
#   detail: "{ \"admin@test\" : { \"user_account_email\" : \"compassionate_nash@email.com\", \"user_account_full_name\" : \"Compassionate Nash\", \"user_account_institution\" : \"Ecole Nationale Sup\303\251rieure des Arts et Industries Textile\", \"user_account_orcid\" : \"4587-5343-1585-X\", \"user_private_key\" : \"b\'43e56590a0e8eeee96d5fdc51af83b85c3be91dba0e83aefc7c0ecfcd1161088\'\", \"user_public_key\" : \"1e5218b0c3a2b64e0fc252263ee9b287cdfffe1c0cc7e59d7c33cf38ec7acd43\", \"user_role\" : \"author\" } }"
#   total_number: 7
# }
# query_hash: "da2388dc432ac61909e491b2c8f3dba983c8b5dff0db93ca3995e6a9f21173f0"
#
# User Account id = {'account_id': 'compassionate_nash@test'}, details = { "admin@test" : { "user_account_email" : "compassionate_nash@email.com", "user_account_full_name" : "Compassionate Nash", "user_account_institution" : "Ecole Nationale Supérieure des Arts et Industries Textile", "user_account_orcid" : "4587-5343-1585-X", "user_private_key" : "b'43e56590a0e8eeee96d5fdc51af83b85c3be91dba0e83aefc7c0ecfcd1161088'", "user_public_key" : "1e5218b0c3a2b64e0fc252263ee9b287cdfffe1c0cc7e59d7c33cf38ec7acd43", "user_role" : "author" } }
# --------------------
# account_detail_response {
#   detail: "{ \"admin@test\" : { \"project_metadata_cid\" : \"QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH\" } }"
#   total_number: 1
# }
# query_hash: "50d10cc09337a01680b413f75d1bd08ef3f1b52cbd001d08c0f5909eaca48b8e"
#
# Project Account id = {'account_id': '82137@test'}, details = { "admin@test" : { "project_metadata_cid" : "QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH" } }

# %% [markdown]
# 4 - Sets details for both User and Project accounts providing a logical link between them for later references.

# %%
entity_id = user_account['account_id']
print(entity_id)
hash = set_account_detail(address, entity_id, "project", project_account['account_id'])

# print ("-" * 20)

entity_id = project_account['account_id']
print(entity_id)
hash = set_account_detail(address, entity_id, "project_owner", user_account['account_id'])
# Out:
# compassionate_nash@test
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# 82137@test
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"

# %% [markdown]
# 5 - Queries the User and Project accounts again and checks the proper setting of details.

# %%
#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=user_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
user_account_data = response.account_detail_response
print(f'User Account id = {user_account}, details = {user_account_data.detail}')
# Out:
# User Account id = {'account_id': 'compassionate_nash@test'}, details = { "admin@test" : { "project" : "82137@test", "user_account_email" : "compassionate_nash@email.com", "user_account_full_name" : "Compassionate Nash", "user_account_institution" : "Ecole Nationale Supérieure des Arts et Industries Textile", "user_account_orcid" : "4587-5343-1585-X", "user_private_key" : "b'43e56590a0e8eeee96d5fdc51af83b85c3be91dba0e83aefc7c0ecfcd1161088'", "user_public_key" : "1e5218b0c3a2b64e0fc252263ee9b287cdfffe1c0cc7e59d7c33cf38ec7acd43", "user_role" : "author" } }

# %%
print ("-" * 20)

#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=project_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
data = response.account_detail_response
print(f'Project Account id = {project_account}, details = {data.detail}')
# Out:
# --------------------
# Project Account id = {'account_id': '82137@test'}, details = { "admin@test" : { "project_metadata_cid" : "QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH", "project_owner" : "compassionate_nash@test" } }

# %% [markdown]
# # Part2 - Querying Project Metadata

# %% [markdown]
# ## Activities
#
# 6 - Queries the user account, locates the project id, queries the project account, gets the metadata and files from IPFS.

# %% [markdown]
# ## Sequence Diagram

# %% [markdown]
# ```mermaid
# %%{
#   init: {
#     'theme': 'base',
#     'themeVariables': {
#       'primaryColor': '#ffffff',
#       'primaryTextColor': '#000000',
#       'primaryBorderColor': '#000000',
#       'lineColor': '#000000',
#       'secondaryColor': '#f4f4f4',
#       'secondaryTextColor': '#000000',
#       'tertiaryColor': '#d3d3d3',
#       'tertiaryTextColor': '#000000',
#       'background': '#ffffff',
#       'actorBkg': '#B4B4B4',
#       'actorTextColor': '#000000',
#       'actorBorder': '#000000',
#       'actorLineColor': '#000000',
#       'signalColor': '#000000',
#       'signalTextColor': '#000000',
#       'activationBorderColor': '#000000',
#       'activationBkgColor': '#d3d3d3',
#       'sequenceNumberColor': '#000000',
#       'noteBkgColor': '#F0F0F0',
#       'noteTextColor': '#000000',
#       'noteBorderColor': '#000000'
#     }
#   }
# }%%
#
# sequenceDiagram
#     participant Platform as "Platform"
#     participant Blockchain as "Iroha 1 Blockchain"
#     participant IPFS as "Interplanetary File System"
#     participant FrontEnd as "Front End"
#
#     Note over Platform, Blockchain: Queries the user account and get the project id
#     Platform->>Blockchain: Query User Account Details
#     Blockchain->>Platform: Query Response
#
#     Note over Platform, Blockchain: Queries the Project Account details and get project metadata CID
#     Platform->>Blockchain: Query Project Account Details
#     Blockchain->>Platform: Query Response
#
#     Note over Platform, IPFS: Process and displays the metadata CID
#     Platform->>IPFS: Sends the project metadata CID
#     IPFS->>Platform: Sends back the project metadata JSON
#     Platform->>FrontEnd: Displays the project metadata JSON
# ```

# %% [markdown]
# 6 - Queries the user account, locates the project id, queries the project account, gets the metadata and files from IPFS.

# %%
from ipfs_functions import *

# Process the account details response
account_details_dict = json.loads(user_account_data.detail)  # Convert the string to a JSON object
ic(account_details_dict)

# Get the value of the dictionary
user_account_metadata = account_details_dict['admin@test']
ic(user_account_metadata['project'])


for key, value in user_account_metadata.items():
    if 'project' in key:  # Check if this is a file CID
            
        ic(key)
        ic(value)
        #Query - GetAccountDetail
        query = iroha.query('GetAccountDetail',account_id = value)
        # ic(query)
        IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
        response = net.send_query(query)
        # ic(response)
        result = response.account_detail_response
        # ic(result)
        # ic(result.detail)        
        # print(f'Project Account id = {value}, details = {result.detail}')
        # details = {result.detail}
        # ic(details)
        # Process the account details response
        details_dict = json.loads(result.detail)  # Convert the string to a JSON object
        # ic(details_dict)

        # # Get the value of the dictionary (the actual file metadata)
        details_metadata = details_dict['admin@test']
        # ic(details_metadata)
        project_metadata_cid = details_metadata['project_metadata_cid']
        # ic(project_metadata_cid)
        project_metadata_json = download_json_from_ipfs(project_metadata_cid)
        ic(project_metadata_json)
# Out:
# ic| account_details_dict: {'admin@test': {'project': '82137@test',
#                                           'user_account_email': 'compassionate_nash@email.com',
#                                           'user_account_full_name': 'Compassionate Nash',
#                                           'user_account_institution': 'Ecole Nationale Supérieure des '
#                                                                       'Arts et Industries Textile',
#                                           'user_account_orcid': '4587-5343-1585-X',
#                                           'user_private_key': "b'43e56590a0e8eeee96d5fdc51af83b85c3be91dba0e83aefc7c0ecfcd1161088'",
#                                           'user_public_key': '1e5218b0c3a2b64e0fc252263ee9b287cdfffe1c0cc7e59d7c33cf38ec7acd43',
#                                           'user_role': 'author'}}
# ic| user_account_metadata['project']: '82137@test'
# ic| key: 'project'
# ic| value: '82137@test'
# ic| project_metadata_json: {'abstract': 'This study aims to investigate the effects of e-waste on public '
#                                         'safety and propose strategies for improvement.',
#                             'end_date': '2022-01-28',
#                             'funding_agency': 'European Union Horizon 2020',
#                             'keywords': ['e-waste', 'public safety', 'ecosystem health'],
#                             'location': 'Lagos, Nigeria',
#                             'start_date': '2019-11-06',
#                             'title': 'Exploring the Effects of e-waste on public safety'}

# %% [markdown]
# # Part 3 - File Operations

# %% [markdown]
# 7 -  Sends every file in the `upload` directory to IPFS, extracts theirs respective metadata with Apache Tika and sends it to IPFS, get the CIDs back and store in Iroha as details of the project account.

# %% [markdown]
# ```mermaid
#
# %%{
#   init: {
#     'theme': 'base',
#     'themeVariables': {
#       'primaryColor': '#ffffff',
#       'primaryTextColor': '#000000',
#       'primaryBorderColor': '#000000',
#       'lineColor': '#000000',
#       'secondaryColor': '#f4f4f4',
#       'secondaryTextColor': '#000000',
#       'tertiaryColor': '#d3d3d3',
#       'tertiaryTextColor': '#000000',
#       'background': '#ffffff',
#       'actorBkg': '#B4B4B4',
#       'actorTextColor': '#000000',
#       'actorBorder': '#000000',
#       'actorLineColor': '#000000',
#       'signalColor': '#000000',
#       'signalTextColor': '#000000',
#       'activationBorderColor': '#000000',
#       'activationBkgColor': '#d3d3d3',
#       'sequenceNumberColor': '#000000',
#       'noteBkgColor': '#F0F0F0',
#       'noteTextColor': '#000000',
#       'noteBorderColor': '#000000'
#     }
#   }
# }%%
#
# sequenceDiagram
#     participant Platform as "Platform"
#     participant Metadata Extractor
#     participant Indexer
#     participant Blockchain as "Iroha 1 Blockchain"
#     participant IPFS as "Interplanetary File System"
#
#     Note over Platform, IPFS: File Operations
#     Platform->>Metadata Extractor: Parse file and extract metadata
#     Platform->>Indexer: Send file metadata for indexing
#     Platform->>IPFS: Store file metadata JSON
#     IPFS->>Platform: Send back file metadata JSON CIDs
#     Platform->>Blockchain: Set file metadata JSON CID as Project Account Details
#     Platform->>IPFS: Upload local file to IPFS
#     IPFS->>Platform: Send back file CIDs
#     Platform->>Blockchain: Set CID as Project Account Details
#     Blockchain->>Platform:Details set successfully
#
# ```

# %%
from tika import parser
from ipfs_functions import *
import icecream as ic

import ipfshttpclient
from whoosh.index import create_in
from whoosh.fields import Schema, TEXT, ID, NUMERIC
from whoosh.qparser import QueryParser
import os
import json  # Added import for json
from tika import parser  # Apache Tika for metadata extraction

# Load configuration from config.json file
config_path = "config.json"  # Update this path as needed
with open(config_path, "r") as f:
    config = json.load(f)

IPFS_ADDRESS = config["IPFS_ADDRESS"]

# Connect to the IPFS node at a specific IP address and port
ipfs_address = f"/dns/{config['IPFS_ADDRESS']}/tcp/{config['IPFS_PORT']}/http"
client = ipfshttpclient.connect(ipfs_address)

# Define schema for indexing (now includes metadata fields from Tika)
schema = Schema(
    cid=ID(stored=True),                 # The IPFS CID
    name=TEXT(stored=True),              # Filename
    size=NUMERIC(stored=True),           # File size
    filetype=TEXT(stored=True),          # File type (MIME type)
    title=TEXT(stored=True),             # Extracted title (from Tika metadata)
    author=TEXT(stored=True),            # Extracted author (from Tika metadata)
    keywords=TEXT(stored=True),          # Extracted keywords (from Tika metadata)
    full_text=TEXT(stored=False),        # Extracted full text of document (if applicable)
)

# Create the index directory
if not os.path.exists("indexdir"):
    os.mkdir("indexdir")

# Create index in the directory
ix = create_in("indexdir", schema)


def parse_documents_in_directory(directory_path):
    index = 1
    writer = ix.writer()  # Open writer here to optimize indexing
    
    for filename in os.listdir(directory_path):
        print(filename)

        if not os.path.basename(filename).startswith('.'):
            file_path = os.path.join(directory_path, filename)
            file_cid = upload_file_to_ipfs(file_path)
            
            variable_1 = f"file_{index}_CID"
            variable_2 = file_cid

            hash = set_account_detail(address, user_account, variable_1, variable_2)

            try:
                parsed_document = parser.from_file(file_path)

                if parsed_document:  # Check if parsing was successful
                    metadata = parsed_document.get('metadata', {})
                    full_text = parsed_document.get("content", "").strip()

                    title = metadata.get("title", "Unknown")
                    author = metadata.get("Author", "Unknown")
                    keywords = metadata.get("Keywords", "")

                    metadata_cid = upload_json_to_ipfs(metadata)

                    # Fetch file stats from IPFS
                    stats = client.object.stat(metadata_cid)
                    file_size = stats['CumulativeSize']

                    # Use mimetypes to get the file type
                    import mimetypes
                    filetype = mimetypes.guess_type(filename)[0] or "unknown"

                    # Index the document
                    writer.add_document(
                        cid=metadata_cid,
                        name=filename,
                        size=file_size,
                        filetype=filetype,
                        title=title,
                        author=author,
                        keywords=keywords,
                        full_text=full_text,  # Index full text for searching
                    )
                    print(f"Indexed {filename} with CID: {metadata_cid}")

                    variable_3 = f"file_{index}_metadata_CID"
                    variable_4 = metadata_cid

                    hash = set_account_detail(address, user_account, variable_3, variable_4)

                else:
                    print(f"Parsing failed for '{filename}'.")

            except Exception as e:
                print(f"Error with file '{filename}': {e}")
                continue

        print("-" * 40)
        index += 1

    writer.commit()  # Commit changes once after all files are processed


# Example usage
parse_documents_in_directory("upload")
# Out:
# Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# 2024-10-13 23:04:38,284 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# 2024-10-13 23:04:44,094 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2024-10-13 23:04:45,252 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# Indexed Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf with CID: QmNMw1q17jaxJNEibpidiQ1XphNpjLi4ZuiFjezes4nktn
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Munafò et al. - 2022 - The reproducibility debate is an opportunity, not .pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Munafò et al. - 2022 - The reproducibility debate is an opportunity, not .pdf with CID: QmbeSMnQ5ntreEcmvnrYTYmShwW8chD1B3MKh2A5qFJBMV
# 	Entering "set_account_detail"
# None
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf with CID: QmSrvYzmjWUmQBLV6h4JurBtYFkw49EcqQAFQndqsFCUpk
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf with CID: QmdGksq7hEzDXjwunf4u6zxvay2KQqkSjmAxKVyQ4Vshq6
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Editorial-Board_2023_Expert-Systems-with-Applications.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Editorial-Board_2023_Expert-Systems-with-Applications.pdf with CID: QmTGEnVox8MwFuRjXvsDSqbbcHgupeZi8ybCr476tC4sMu
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf with CID: QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN
# 	Entering "set_account_detail"
# None
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# World_Energy_By_Country_And_Region_1965_to_2023.csv
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed World_Energy_By_Country_And_Region_1965_to_2023.csv with CID: QmbAF8aBRpUQCK9ujk6NNjwDxvwyo1AgARS5611dZ5pDZz
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf with CID: QmbZ9xqB6uXFZQKe9Bx69nmJSJ5eNhbNpTpjxYm9bsowvm
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Jean-Baptiste_Perronneau_-_Magdaleine_Pinceloup_de_la_Grange,_née_de_Parseval.jpg
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Error with file 'Jean-Baptiste_Perronneau_-_Magdaleine_Pinceloup_de_la_Grange,_née_de_Parseval.jpg': 'NoneType' object has no attribute 'strip'
# bitcoin.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed bitcoin.pdf with CID: QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# Random-feature-selection-using-random-subspace-l_2023_Expert-Systems-with-Ap.pdf
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed Random-feature-selection-using-random-subspace-l_2023_Expert-Systems-with-Ap.pdf with CID: QmZvj1BrrG3XCR6x7V6Wymxk7bXAJNxqsv8GNXuW52FuVW
# 	Entering "set_account_detail"
# None
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------
# hello_world.py
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# Indexed hello_world.py with CID: QmPDE69isvBDk8gaMYWCWNE7KoqVs746oejZixveLC6qjs
# 	Entering "set_account_detail"
# None
# ('STATELESS_VALIDATION_SUCCESS', 1, 0)
# ('ENOUGH_SIGNATURES_COLLECTED', 9, 0)
# ('STATEFUL_VALIDATION_SUCCESS', 3, 0)
# ('COMMITTED', 5, 0)
# 	Leaving "set_account_detail"
# ----------------------------------------

# %%
def search_ipfs(keyword):
    with ix.searcher() as searcher:
        query = QueryParser("full_text", ix.schema).parse(keyword)
        results = searcher.search(query)

        if results:
            for result in results:
                print(f"CID: {result['cid']}, Name: {result['name']}, Title: {result['title']}, Author: {result['author']}, Size: {result['size']} bytes")
        else:
            print(f"No results found for '{keyword}'")


# Example search
search_ipfs("longer")
# Out:
# CID: QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX, Name: bitcoin.pdf, Title: Unknown, Author: Unknown, Size: 1569 bytes
# CID: QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN, Name: COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf, Title: Unknown, Author: Unknown, Size: 3851 bytes

# %% [markdown]
# 8 - Query the project account to verify the details update

# %%
print ("-" * 20)

#Query - GetAccountDetail
query = iroha.query('GetAccountDetail',account_id=project_account['account_id'])
IrohaCrypto.sign_query(query, ADMIN_PRIVATE_KEY)
response = net.send_query(query)
data = response.account_detail_response
print(f'Project Account id = {project_account}, details = {data.detail}')
# Out:
# --------------------
# Project Account id = {'account_id': '82137@test'}, details = { "admin@test" : { "file_10_CID" : "QmTLZSqzPexwEdniZXLPN6fUfmEXX6MXS3b4QjKURgxc9y", "file_10_metadata_CID" : "QmZvj1BrrG3XCR6x7V6Wymxk7bXAJNxqsv8GNXuW52FuVW", "file_11_CID" : "QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv", "file_11_metadata_CID" : "QmPDE69isvBDk8gaMYWCWNE7KoqVs746oejZixveLC6qjs", "file_1_CID" : "QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs", "file_1_metadata_CID" : "QmNMw1q17jaxJNEibpidiQ1XphNpjLi4ZuiFjezes4nktn", "file_2_CID" : "QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW", "file_2_metadata_CID" : "QmbeSMnQ5ntreEcmvnrYTYmShwW8chD1B3MKh2A5qFJBMV", "file_3_CID" : "QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C", "file_3_metadata_CID" : "QmSrvYzmjWUmQBLV6h4JurBtYFkw49EcqQAFQndqsFCUpk", "file_4_CID" : "QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4", "file_4_metadata_CID" : "QmdGksq7hEzDXjwunf4u6zxvay2KQqkSjmAxKVyQ4Vshq6", "file_5_CID" : "QmZnh5Uuo7moZKMESFHpRjQFbbND5e3nArCzZg8uLARAgg", "file_5_metadata_CID" : "QmTGEnVox8MwFuRjXvsDSqbbcHgupeZi8ybCr476tC4sMu", "file_6_CID" : "QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW", "file_6_metadata_CID" : "QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN", "file_7_CID" : "QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ", "file_7_metadata_CID" : "QmbAF8aBRpUQCK9ujk6NNjwDxvwyo1AgARS5611dZ5pDZz", "file_8_CID" : "QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q", "file_8_metadata_CID" : "QmbZ9xqB6uXFZQKe9Bx69nmJSJ5eNhbNpTpjxYm9bsowvm", "file_9_CID" : "QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj", "file_9_metadata_CID" : "QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX", "project_metadata_cid" : "QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH", "project_owner" : "compassionate_nash@test" } }

# %% [markdown]
# 9 - Read CIDs from Iroha and download file metadata and files from IPFS to the project home directory

# %% [markdown]
# ```mermaid
# %%{
#   init: {
#     'theme': 'base',
#     'themeVariables': {
#       'primaryColor': '#ffffff',
#       'primaryTextColor': '#000000',
#       'primaryBorderColor': '#000000',
#       'lineColor': '#000000',
#       'secondaryColor': '#f4f4f4',
#       'secondaryTextColor': '#000000',
#       'tertiaryColor': '#d3d3d3',
#       'tertiaryTextColor': '#000000',
#       'background': '#ffffff',
#       'actorBkg': '#B4B4B4',
#       'actorTextColor': '#000000',
#       'actorBorder': '#000000',
#       'actorLineColor': '#000000',
#       'signalColor': '#000000',
#       'signalTextColor': '#000000',
#       'activationBorderColor': '#000000',
#       'activationBkgColor': '#d3d3d3',
#       'sequenceNumberColor': '#000000',
#       'noteBkgColor': '#F0F0F0',
#       'noteTextColor': '#000000',
#       'noteBorderColor': '#000000'
#     }
#   }
# }%%
#
# sequenceDiagram
#     participant Platform as "Platform"
#     participant Blockchain as "Iroha 1 Blockchain"
#     participant IPFS as "Interplanetary File System"
#     participant FrontEnd as "Front End"
#
#     Note over Platform, Blockchain: Queries the Project Account details and get details
#     Platform->>Blockchain: Query Project Account Details
#     Blockchain->>Platform: Query Response
#
#     Note over Platform, IPFS: Process project account metadata
#     Platform->>Platform: Parse Project Details JSON and retrieve file CIDs
#
#     Note over Platform, IPFS: Download file from IPFS
#     Platform->>IPFS: Sends the file CID
#     IPFS->>Platform: Sends back the file
#     Platform->>FrontEnd:    Saves the file locally and display info and status

# %% [markdown]
# 10 - Read details from the project account retrieve the CID of every file, download the it file from IPFS and store locally.

# %%
from ipfs_functions import *
from clean_file_name import *

# Process the account details response
account_details_dict = json.loads(data.detail)  # Convert the string to a JSON object
ic(account_details_dict)

# Get the value of the dictionary (the actual file metadata)
files_metadata = account_details_dict['admin@test']
ic(files_metadata)

for key, value in files_metadata.items():
    if 'metadata_CID' not in key:  # Check if this is a file CID
        key = '_'.join(key.split('_')[:-1])+"_CID"    
        # ic(key)
        file_CID = value
        # ic(value)
        
    else:
        file_metadata_key = '_'.join(key.split('_')[:-2])  # Extract the actual filename from the key
        ic(file_metadata_key)
        file_metadata_CID = value  # Get the corresponding metadata CID
        ic(file_metadata_CID)
        # print(f"Downloading {file_metadata_CID} metadata...")
        file_metadata_json = download_json_from_ipfs(file_metadata_CID)
        # ic(file_metadata_json)
        if 'resourceName' in file_metadata_json:  # check if key exists in the dictionary
            raw_original_file_name = file_metadata_json['resourceName']
            ic(raw_original_file_name)
            clean_original_file_name = clean_file_name(raw_original_file_name)  # Remove the 'b' prefix and quotes
            ic(clean_original_file_name)

            # Create a home directory for the user with the account ID as the username under /download/
            user_id = project_account['account_id']
            download_directory = os.path.join("download", user_id)
            if not os.path.exists(download_directory):
                os.makedirs(download_directory)  # Create the directory if it doesn't exist

            file_path = os.path.join(download_directory, clean_original_file_name)
            download_file_from_ipfs(file_CID, file_path)
# Out:
# ic| account_details_dict: {'admin@test': {'file_10_CID': 'QmTLZSqzPexwEdniZXLPN6fUfmEXX6MXS3b4QjKURgxc9y',
#                                           'file_10_metadata_CID': 'QmZvj1BrrG3XCR6x7V6Wymxk7bXAJNxqsv8GNXuW52FuVW',
#                                           'file_11_CID': 'QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv',
#                                           'file_11_metadata_CID': 'QmPDE69isvBDk8gaMYWCWNE7KoqVs746oejZixveLC6qjs',
#                                           'file_1_CID': 'QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs',
#                                           'file_1_metadata_CID': 'QmNMw1q17jaxJNEibpidiQ1XphNpjLi4ZuiFjezes4nktn',
#                                           'file_2_CID': 'QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW',
#                                           'file_2_metadata_CID': 'QmbeSMnQ5ntreEcmvnrYTYmShwW8chD1B3MKh2A5qFJBMV',
#                                           'file_3_CID': 'QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C',
#                                           'file_3_metadata_CID': 'QmSrvYzmjWUmQBLV6h4JurBtYFkw49EcqQAFQndqsFCUpk',
#                                           'file_4_CID': 'QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4',
#                                           'file_4_metadata_CID': 'QmdGksq7hEzDXjwunf4u6zxvay2KQqkSjmAxKVyQ4Vshq6',
#                                           'file_5_CID': 'QmZnh5Uuo7moZKMESFHpRjQFbbND5e3nArCzZg8uLARAgg',
#                                           'file_5_metadata_CID': 'QmTGEnVox8MwFuRjXvsDSqbbcHgupeZi8ybCr476tC4sMu',
#                                           'file_6_CID': 'QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW',
#                                           'file_6_metadata_CID': 'QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN',
#                                           'file_7_CID': 'QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ',
#                                           'file_7_metadata_CID': 'QmbAF8aBRpUQCK9ujk6NNjwDxvwyo1AgARS5611dZ5pDZz',
#                                           'file_8_CID': 'QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q',
#                                           'file_8_metadata_CID': 'QmbZ9xqB6uXFZQKe9Bx69nmJSJ5eNhbNpTpjxYm9bsowvm',
#                                           'file_9_CID': 'QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj',
#                                           'file_9_metadata_CID': 'QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX',
#                                           'project_metadata_cid': 'QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH',
#                                           'project_owner': 'compassionate_nash@test'}}
# ic| files_metadata: {'file_10_CID': 'QmTLZSqzPexwEdniZXLPN6fUfmEXX6MXS3b4QjKURgxc9y',
#                      'file_10_metadata_CID': 'QmZvj1BrrG3XCR6x7V6Wymxk7bXAJNxqsv8GNXuW52FuVW',
#                      'file_11_CID': 'QmeBTz4ZwyqPkPigpASZ3wJodBXzJRpeXQMwNcsWRqU5Jv',
#                      'file_11_metadata_CID': 'QmPDE69isvBDk8gaMYWCWNE7KoqVs746oejZixveLC6qjs',
#                      'file_1_CID': 'QmT7ximApXtExAedhzUHGHDwRismRzuKykpH4dgTvGrNZs',
#                      'file_1_metadata_CID': 'QmNMw1q17jaxJNEibpidiQ1XphNpjLi4ZuiFjezes4nktn',
#                      'file_2_CID': 'QmdiRawzVNUiB28ENKQ7WefeFLEJ1xMjsJjwtHL2jnJ9xW',
#                      'file_2_metadata_CID': 'QmbeSMnQ5ntreEcmvnrYTYmShwW8chD1B3MKh2A5qFJBMV',
#                      'file_3_CID': 'QmXquoApMLCcauNkz4tYw1Sp2tsqZ4edv1YtnQi5pmbw6C',
#                      'file_3_metadata_CID': 'QmSrvYzmjWUmQBLV6h4JurBtYFkw49EcqQAFQndqsFCUpk',
#                      'file_4_CID': 'QmXh37WXcrLXkJX2cAPjbPdKZ2cxJXD58XX6eU1Zc41ka4',
#                      'file_4_metadata_CID': 'QmdGksq7hEzDXjwunf4u6zxvay2KQqkSjmAxKVyQ4Vshq6',
#                      'file_5_CID': 'QmZnh5Uuo7moZKMESFHpRjQFbbND5e3nArCzZg8uLARAgg',
#                      'file_5_metadata_CID': 'QmTGEnVox8MwFuRjXvsDSqbbcHgupeZi8ybCr476tC4sMu',
#                      'file_6_CID': 'QmUq29KRwpTdvScB5oYzEDobDHyb4N1f9eaZXm4VaMCgiW',
#                      'file_6_metadata_CID': 'QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN',
#                      'file_7_CID': 'QmSSY49SnmbCZ3oSaTki7CYZe1ZaWZfE1CsWHpt8Ge7acJ',
#                      'file_7_metadata_CID': 'QmbAF8aBRpUQCK9ujk6NNjwDxvwyo1AgARS5611dZ5pDZz',
#                      'file_8_CID': 'QmV1vYkuiwKGPA5Tyi4ECNFfWYocyTtQ3E5j7CSvPBX49Q',
#                      'file_8_metadata_CID': 'QmbZ9xqB6uXFZQKe9Bx69nmJSJ5eNhbNpTpjxYm9bsowvm',
#                      'file_9_CID': 'QmRA3NWM82ZGynMbYzAgYTSXCVM14Wx1RZ8fKP42G6gjgj',
#                      'file_9_metadata_CID': 'QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX',
#                      'project_metadata_cid': 'QmcmVYa2kMLJg6sYbFHCAwqEYraDBaKd92UdBRec3xTZEH',
#                      'project_owner': 'compassionate_nash@test'}
# ic| file_metadata_key: 'file_10'
# ic| file_metadata_CID: 'QmZvj1BrrG3XCR6x7V6Wymxk7bXAJNxqsv8GNXuW52FuVW'
# ic| raw_original_file_name: "b'Random-feature-selection-using-random-subspace-l_2023_Expert-Systems-with-Ap.pdf'"
# ic| clean_original_file_name: 'Random-feature-selection-using-random-subspace-l_2023_Expert-Systems-with-Ap.pdf'
# ic| file_metadata_key: 'file_11'
# ic| file_metadata_CID: 'QmPDE69isvBDk8gaMYWCWNE7KoqVs746oejZixveLC6qjs'
# ic| raw_original_file_name: "b'hello_world.py'"
# ic| clean_original_file_name: 'hello_world.py'
# ic| file_metadata_key: 'file_1'
# ic| file_metadata_CID: 'QmNMw1q17jaxJNEibpidiQ1XphNpjLi4ZuiFjezes4nktn'
# ic| raw_original_file_name: "b'Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf'"
# ic| clean_original_file_name: 'Diabetic-retinopathy-identification-using-parallel-convo_2023_Expert-Systems.pdf'
# ic| file_metadata_key: 'file_2'
# ic| file_metadata_CID: 'QmbeSMnQ5ntreEcmvnrYTYmShwW8chD1B3MKh2A5qFJBMV'
# ic| raw_original_file_name: ("b'Munaf\\xc3\\xb2 et al. - 2022 - The reproducibility debate is an "
#                              "opportunity, not .pdf'")
# ic| clean_original_file_name: 'Munafò et al. - 2022 - The reproducibility debate is an opportunity, not .pdf'
# ic| file_metadata_key: 'file_3'
# ic| file_metadata_CID: 'QmSrvYzmjWUmQBLV6h4JurBtYFkw49EcqQAFQndqsFCUpk'
# ic| raw_original_file_name: "b'Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf'"
# ic| clean_original_file_name: 'Mel-Spectrogram-based-advanced-deep-temporal-clusterin_2023_Expert-Systems-w.pdf'
# ic| file_metadata_key: 'file_4'
# ic| file_metadata_CID: 'QmdGksq7hEzDXjwunf4u6zxvay2KQqkSjmAxKVyQ4Vshq6'
# ic| raw_original_file_name: "b'Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf'"
# ic| clean_original_file_name: 'Aeroacoustic-airfoil-shape-optimization-enhance_2023_Expert-Systems-with-App.pdf'
# ic| file_metadata_key: 'file_5'
# ic| file_metadata_CID: 'QmTGEnVox8MwFuRjXvsDSqbbcHgupeZi8ybCr476tC4sMu'
# ic| raw_original_file_name: "b'Editorial-Board_2023_Expert-Systems-with-Applications.pdf'"
# ic| clean_original_file_name: 'Editorial-Board_2023_Expert-Systems-with-Applications.pdf'
# ic| file_metadata_key: 'file_6'
# ic| file_metadata_CID: 'QmXPeXT5BHrwpB99kfF3nP2QLpfJD23qqQuTiWxnoArNCN'
# ic| raw_original_file_name: "b'COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf'"
# ic| clean_original_file_name: 'COVID19-MLSF--A-multi-task-learning-based-stock-market_2023_Expert-Systems-w.pdf'
# ic| file_metadata_key: 'file_7'
# ic| file_metadata_CID: 'QmbAF8aBRpUQCK9ujk6NNjwDxvwyo1AgARS5611dZ5pDZz'
# ic| raw_original_file_name: "b'World_Energy_By_Country_And_Region_1965_to_2023.csv'"
# ic| clean_original_file_name: 'World_Energy_By_Country_And_Region_1965_to_2023.csv'
# ic| file_metadata_key: 'file_8'
# ic| file_metadata_CID: 'QmbZ9xqB6uXFZQKe9Bx69nmJSJ5eNhbNpTpjxYm9bsowvm'
# ic| raw_original_file_name: "b'Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf'"
# ic| clean_original_file_name: 'Deep-learning-in-insurance--Accuracy-and-model-int_2023_Expert-Systems-with-.pdf'
# ic| file_metadata_key: 'file_9'
# ic| file_metadata_CID: 'QmUV6uNPMZZ5HVK3wjs79fkLu4KMWHT36R1Lds3vVWe3oX'
# ic| raw_original_file_name: "b'bitcoin.pdf'"
# ic| clean_original_file_name: 'bitcoin.pdf'
